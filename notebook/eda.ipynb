# %%
import pandas as pd
import os, sys
sys.path.append(os.path.abspath(os.path.join('..', 'scripts')))
from preprocess_and_eda import EDA
df= pd.read_csv('../data/data.csv')
eda=EDA(df)

# %%
eda.structure()
# Out:
# 2025-01-24 12:05:31,625- INFO-Printing datasets shape....
# (95662, 16)

# %%
eda.check_missing_values()
# Out:
# 2025-01-24 12:05:45,707- INFO-Counting and suming missing value....
# TransactionId           0
# BatchId                 0
# AccountId               0
# SubscriptionId          0
# CustomerId              0
# CurrencyCode            0
# CountryCode             0
# ProviderId              0
# ProductId               0
# ProductCategory         0
# ChannelId               0
# Amount                  0
# Value                   0
# TransactionStartTime    0
# PricingStrategy         0
# FraudResult             0
# dtype: int64

# %%
eda.datatypes()
# Out:
# 2025-01-24 12:15:34,988- INFO-Printing data types....
# TransactionId            object
# BatchId                  object
# AccountId                object
# SubscriptionId           object
# CustomerId               object
# CurrencyCode             object
# CountryCode               int64
# ProviderId               object
# ProductId                object
# ProductCategory          object
# ChannelId                object
# Amount                  float64
# Value                     int64
# TransactionStartTime     object
# PricingStrategy           int64
# FraudResult               int64
# dtype: object

# %%
eda.numeric_dis('Amount')
# Out:
# 2025-01-24 12:06:39,284- INFO-Plotting numeric distribution....

# %%
eda.catagorical_dis('CustomerId')
# Out:
# 2025-01-24 20:41:31,771- INFO-Plotting catagorical distribution....
# CustomerId
# CustomerId_7343    4091
# CustomerId_3634    2085
# CustomerId_647     1869
# CustomerId_1096     784
# CustomerId_4033     778
#                    ...
# CustomerId_5199       1
# CustomerId_7435       1
# CustomerId_4750       1
# CustomerId_1887       1
# CustomerId_2067       1
# Name: count, Length: 3742, dtype: int64

# %%
eda.correlation()
# Out:
# 2025-01-24 12:08:34,058- INFO-Calculating correlation....
# 0.9896921359901101

# %%
eda.skewed('Amount')
# Out:
# 2025-01-24 12:09:00,191- INFO-plotting skewed data....

# %%
eda.cred_dept()
# Out:
# 2025-01-24 12:11:28,108- INFO-Calculating total debt and credit....
# Total debt: 792796736.0 (84.08%)
# Total credit: 150154110.49999997 (15.92%)
